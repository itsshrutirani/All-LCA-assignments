# %%
# PS: To find largest of three numbers
num1=float(input("Enter the first number:"))
num2=float(input("Enter the second number:"))
num3=float(input("Enter the third number:"))
if num3<num1>num2:
   largest=num1
elif num1<num2>num3:
    largest=num2
else: largest=num3

print("largest number is:", largest)
# Out:
# Enter the first number: 47
# Enter the second number: 72
# Enter the third number: 56
# largest number is: 72.0
