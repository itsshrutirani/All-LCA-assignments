# %%
#STUDENT DATA MANAGEMENT USING PYTHON COLLECTIONS(DICTIONARY, LISTS & TUPLE)
Students={
    101:("shruti","CSE",[76,87,93]),
    102:("aarya","CSE(AIDS)",[81,95,75]),
    103:("anushka","ECE",[84,94,76])
}
print("Original Student Records")
print(Students)

#Adding a new student record
Students[104]=("alfiya","mechanical",[76,82,96])
print("\nAfter adding new student:")
print(Students)

#Deleting an existing student record
del Students[101]
print("\nAfter deleting student 101:")
print(Students)

#Updating details of a student
Students[102]=("akansha","civil",[85,96,72])
print("\nAfter updating student 102:")
print(Students)

#Displaying final records
print("\nFinal student records")
for Roll_Number in Students:
    print("\nRoll Number:",Roll_Number)
    print("Name:",Students[Roll_Number][0])
    print("Branch:",Students[Roll_Number][1])
    print("Marks:",Students[Roll_Number][2])
# Out:
# Original Student Records
# {101: ('shruti', 'CSE', [76, 87, 93]), 102: ('aarya', 'CSE(AIDS)', [81, 95, 75]), 103: ('anushka', 'ECE', [84, 94, 76])}
#
# After adding new student:
# {101: ('shruti', 'CSE', [76, 87, 93]), 102: ('aarya', 'CSE(AIDS)', [81, 95, 75]), 103: ('anushka', 'ECE', [84, 94, 76]), 104: ('alfiya', 'mechanical', [76, 82, 96])}
#
# After deleting student 101:
# {102: ('aarya', 'CSE(AIDS)', [81, 95, 75]), 103: ('anushka', 'ECE', [84, 94, 76]), 104: ('alfiya', 'mechanical', [76, 82, 96])}
#
# After updating student 102:
# {102: ('akansha', 'civil', [85, 96, 72]), 103: ('anushka', 'ECE', [84, 94, 76]), 104: ('alfiya', 'mechanical', [76, 82, 96])}
#
# Final student records
#
# Roll Number: 102
# Name: akansha
# Branch: civil
# Marks: [85, 96, 72]
#
# Roll Number: 103
# Name: anushka
# Branch: ECE
# Marks: [84, 94, 76]
#
# Roll Number: 104
# Name: alfiya
# Branch: mechanical
# Marks: [76, 82, 96]
