# %%
#
side1=int(input("Enter first side length:"))
side2=int(input("Enter second side length:"))
side3=int(input("Enter third side length:"))

if (side1**2+side2**2==side3**2) or (side2**2+side3**2==side1**2) or (side1**2+side3**2==side2**2):
   print("it is a right angled triange")
else:
   print("it is not an right angles triangle")
# Out:
# Enter first side length: 3
# Enter second side length: 4
# Enter third side length: 5
# it is a right angled triange
